# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [18.0, 10.0]
plt.style.use('ggplot')
import pandas as pd
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [18.0, 8.0]
import re
import string

# %%
Data = pd.read_excel('Freq.xlsx', sep='\t',
                     names = ["Año", "Número_de_leyes"])
Data_df = pd.DataFrame(Data)

# %%
set(Data)
# Out:
# {'Año', 'Número_de_leyes'}

# %%
type(Data)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt
x = Data["Año"]
# create an index for each tick position
xi = [i for i in range(0, len(x))]
y = Data["Número_de_leyes"]
# plot the index for the x-values
plt.plot(xi, y, marker='o', linestyle='--', color='r', label='Leyes') 
plt.xlabel('x')
plt.ylabel('y') 
plt.xticks(xi, x)
plt.title('Leyes')
plt.legend() 
plt.show()

# %%
Data.loc()

# %%
Data.set_xlabel("Año", fontsize=12)
Data.set_ylabel("número de leyes", fontsize=12)
plt.show()
plt.title("My graph")
plt.xlabel("Some x values")
plt.ylabel("Some y values")
plt.axhline(0, color="gray", linestyle="--")
plt.axvline(0, color="gray", linestyle="--")
plt.plot(xs,ys);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-8901d9cac260> in <module>()
# ----> 1 Data.set_xlabel("Año", fontsize=12)
#       2 Data.set_ylabel("número de leyes", fontsize=12)
#       3 plt.show()
#       4 plt.title("My graph")
#       5 plt.xlabel("Some x values")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'set_xlabel'

# %%
Data2 = pd.read_excel('FreqR.xlsx', sep='\t',
                     names = ["Año", "Número_de_Resoluciones"])
Data2_df = pd.DataFrame(Data2)

# %%
import matplotlib.pyplot as plt
x = Data2["Año"]
# create an index for each tick position
xi = [i for i in range(0, len(x))]
y = Data2["Número_de_Resoluciones"]
# plot the index for the x-values
plt.plot(xi, y, marker='o', linestyle='--', color='r', label='Nro de Resoluciones') 
plt.xlabel('x')
plt.ylabel('y') 
plt.xticks(xi, x)
plt.title('Resoluciones')
plt.legend() 
plt.show()
