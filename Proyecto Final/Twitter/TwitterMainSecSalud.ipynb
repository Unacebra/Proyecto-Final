# %%
import tweepy           
import pandas as pd     
import numpy as np      

from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from credentials import *   
def twitter_setup():
    """

    """

    auth = tweepy.OAuthHandler("efaLfD1FCQN1Osywaj6fjIV4R", "uYt7uuNhG7YYBJmivxzrsZPPOV1TCqizLLxnEwmYRnWV4W9zqa")
    auth.set_access_token("985156748687355904-FzoJLdbfuifMhhEP3U30FDaQmAdRoWD", "ASNpaQBzV705MW4f268EjlhLXSiarsMTU7b9QJEPy1XO5")


    api = tweepy.API(auth)
    return api

# %%
extractor = twitter_setup()
 ###Para resolver el problema de IOPub rate exceeded correr:jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000000 en Anaconda Prompor

tweets = extractor.user_timeline(screen_name="SectorSalud", count=600,)
print("Number of tweets extracted: {}.\n".format(len(tweets)))


print(tweets)
# Out:
# Number of tweets extracted: 200.
#
# [Status(_api=<tweepy.api.API object at 0x000001EEF3ED88D0>, _json={'created_at': 'Thu May 17 13:30:33 +0000 2018', 'id': 997107105462128640, 'id_str': '997107105462128640', 'text': 'RT @CanalCapital: ¡Gracias por estar siempre ahí!\nEl corazón de la ciudad late con el inmenso apoyo de miles de trabajadores de la salud. P…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'CanalCapital', 'name': 'Canal Capital', 'id': 252134272, 'id_str': '252134272', 'indices': [3, 16]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 241135651, 'id_str': '241135651', 'name': 'SecretaríaSaludBogta', 'screen_name': 'SectorSalud', 'location': 'Bogotá', 'description': 'Twitter oficial de la Secretaría de Salud de Bogotá.\nSecretario de Salud Dr. Luis Gonzalo Morales @luismorales0621\nSíguenos en Facebook https://t.co/25w17yNM2r', 'url': 'https://t.co/nK2XoC1Gz9', 'entities': {'url': {'urls': [{'url': 'https://t.co/nK2XoC1Gz9', 'expanded_url': 'http://www.saludcapital.gov.co', 'display_url': 'saludcapital.gov.co', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/25w17yNM2r', 'expanded_url': 'https://bit.ly/2IrAWg5', 'display_url': 'bit.ly/2IrAWg5', 'indices': [136, 159]}]}}, 'protected': False, 'followers_count': 52461, 'friends_count': 576, 'listed_count': 292, 'created_at': 'Fri Jan 21 15:06:18 +0000 2011', 'favourites_count': 2448, 'utc_offset': -18000, 'time_zone': 'America/Bogota', 'geo_enabled': True, 'verified': True, 'statuses_count': 75381, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0999B9', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/693156014670102528/Gl6wfKH4.jpg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/693156014670102528/Gl6wfKH4.jpg', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/984045784336355328/B9fUjqlz_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/984045784336355328/B9fUjqlz_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/241135651/1524483368', 'profile_link_color': '0999B9', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'D7FF36', 'profile_text_color': '574F57', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu May 17 13:30:00 +0000 2018', 'id': 997106965703639040, 'id_str': '997106965703639040', 'text': '¡Gracias por estar siempre ahí!\nEl corazón de la ciudad late con el inmenso apoyo de miles de trabajadores de la sa… https://t.co/lsQWZZO7mB', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/lsQWZZO7mB', 'expanded_url': 'https://twitter.com/i/web/status/997106965703639040', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 252134272, 'id_str': '252134272', 'name': 'Canal Capital', 'screen_name': 'CanalCapital', 'location': 'Bogotá, Colombia', 'description': 'Somos el canal público de Bogotá. Encuentre aquí las noticias más importantes de la ciudad. Dirige @YesidLancheros', 'url': 'https:/ ...

# %%
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# %%
data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID']   = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

# %%
data
# Out:
#                                                 Tweets  len  \
# 0    RT @CanalCapital: ¡Gracias por estar siempre a...  140
# 1    ¿Sabes por qué en el sector salud de Bogotá to...  129
# 2    Cerca de 20 mil colaboradores relataron su día...  130
# 3    RT @GobiernoBTA: Gobierno va con toda en el Re...  140
# 4    #BuenasNoticias En #LaNuevaBogotá ya son 20 Ce...  140
# 5    La Subred Sur Occidente cuenta con 5 Centros d...  140
# 6    La Subred Centro Oriente cuenta con 4 Centros ...  139
# 7    Los Centros de Atención Prioritaria en Salud C...  140
# 8    Los Centros de Atención Prioritaria en Salud h...  140
# 9    Ahora más bogotanos pueden acceder a los servi...  140
# 10   RT @CanalCapital: Hemos destinado 250 mil mill...  140
# 11   #FelizJueves Ya son 20 Centros de Atención Pri...  137
# 12   #RespiraSinIRA Evita la transmisión de infecci...  116
# 13   #RespiraSinIRA Evita que a quien esté a tu lad...   94
# 14   RT @integracionbta: Hoy 191 habitantes de call...  139
# 15   #RespiraSinIRA Consulta al médico si tienes al...   92
# 16   #QueOrgullo Durante la administración del alca...  139
# 17   #QueOrgullo Conoce nuestra nueva Unidad Pediát...  120
# 18   El reconocimiento #CorazónImparable 💓 es para:...  140
# 19   El reconocimiento #CorazónValiente 💓 es para:\...  140
# 20   #RespiraSinIRA ¡Cuidado! Si tu hijo menor de 5...  135
# 21   El reconocimiento #CorazónInnovador 💓 es para:...  140
# 22   RT @CanalCapital: ¡Gracias por estar siempre a...  140
# 23   RT @CanalCapital: Alcaldía de @EnriquePenalosa...  140
# 24   El reconocimiento #CorazónImparable 💓  A los c...  140
# 25   Hoy entregaremos el reconocimiento #CorazónVal...  139
# 26   RT @EnriquePenalosa: En evento justo y bello d...  140
# 27   RT @Capitalsalud: El reconocimiento #CorazónAn...  140
# 28   Hoy entregaremos el reconocimiento #CorazónInn...  140
# 29   Hoy entregaremos el reconocimiento #CorazónAma...  140
# ..                                                 ...  ...
# 170  Sabemos que la familia es el tesoro más precia...  140
# 171  Celebra con los tuyos el Día de las Familias q...  119
# 172  En el día de la familia, queremos conocer quié...  140
# 173  Todos podemos hacer las labores del hogar 🏡, g...  140
# 174  RT @integracionbta: Como acto simbólico, hoy n...  140
# 175  RT @SubRedSurOcci: Las madres pueden estar tra...  140
# 1  ¿Sabes por qué en el sector salud de Bogotá to...  129  997106733754605569
# 2  Cerca de 20 mil colaboradores relataron su día...  130  997100833014677504
# 3  RT @GobiernoBTA: Gobierno va con toda en el Re...  140  997097926525640705
# 4  #BuenasNoticias En #LaNuevaBogotá ya son 20 Ce...  140  997082108739948544
# 5  La Subred Sur Occidente cuenta con 5 Centros d...  140  997081541028274176
# 6  La Subred Centro Oriente cuenta con 4 Centros ...  139  997081289734918150
# 7  Los Centros de Atención Prioritaria en Salud C...  140  997081051716603904
# 8  Los Centros de Atención Prioritaria en Salud h...  140  997080854013849600
# 9  Ahora más bogotanos pueden acceder a los servi...  140  997080711629869057
#
#                  Date               Source  Likes  RTs
# 0 2018-05-17 13:30:33  Twitter for Android      0    1
# 1 2018-05-17 13:29:05         Media Studio      3    5
# 2 2018-05-17 13:05:38         Media Studio      0    2
# 3 2018-05-17 12:54:05   Twitter Web Client      0  106
# 4 2018-05-17 11:51:14  Twitter for Android      1    3
# 5 2018-05-17 11:48:58  Twitter for Android      0    0
# 6 2018-05-17 11:47:59  Twitter for Android      0    0
# 7 2018-05-17 11:47:02  Twitter for Android      0    0
# 8 2018-05-17 11:46:15  Twitter for Android      0    0
# 9 2018-05-17 11:45:41  Twitter for Android      2    1

# %%
mean = np.mean(data['len'])

print("La longitud promedio de los caracteres de los tweets de la Secretaria de Salud es: {}".format(mean))
# Out:
# La longitud promedio de los caracteres de los tweets de la Secretaria de Salud es: 133.75

# %%
fav_max = np.max(data['Likes'])
rt_max  = np.max(data['RTs'])

fav = data[data.Likes == fav_max].index[0]
rt  = data[data.RTs == rt_max].index[0]

# Max FAVs:
print("El tweet con más likes es: \n{}".format(data['Tweets'][fav]))
print("El número de likes es: {}".format(fav_max))
print("{} characters.\n".format(data['len'][fav]))

# Max RTs:
print("El tweets con más retweets es: \n{}".format(data['Tweets'][rt]))
print("Número de retweets: {}".format(rt_max))
print("{} characters.\n".format(data['len'][rt]))
# Out:
# El tweet con más likes es:
# Reconocimientos #HechosDeCorazón 💓 valoran el trabajo a través de 6 categorías a todos los colaboradores del sector… https://t.co/b7qBGgUQ0S
# El número de likes es: 22
# 140 characters.
#
# El tweets con más retweets es:
# RT @GobiernoBTA: Gobierno va con toda en el Reto #MáximaVelocidadGOB de @Ministerio_TIC 🏁🏆
#
# #FastGobierno es la escudería con la que estamo…
# Número de retweets: 106
# 140 characters.

# %%
tlen = pd.Series(data=data['len'].values, index=data['Date'])
tfav = pd.Series(data=data['Likes'].values, index=data['Date'])
tret = pd.Series(data=data['RTs'].values, index=data['Date'])

# %%
tlen.plot(figsize=(16,4), color='g');

# %%
tfav.plot(figsize=(16,4), label="Likes", legend=True)
tret.plot(figsize=(16,4), label="Retweets", legend=True);

# %%
sources = []
for source in data['Source']:
    if source not in sources:
        sources.append(source)


print("Creation of content sources:")
for source in sources:
    print("* {}".format(source))
# Out:
# Creation of content sources:
# * Twitter for Android
# * Media Studio
# * Twitter Web Client
# * TweetDeck
# * Buffer

# %%
percent = np.zeros(len(sources))

for source in data['Source']:
    for index in range(len(sources)):
        if source == sources[index]:
            percent[index] += 1
            pass

percent /= 100

# Pie chart:
pie_chart = pd.Series(percent, index=sources, name='Sources')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6));

# %%
from textblob import TextBlob
import re

# %%
def clean_tweet(tweet):

    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])

display(data.head(10))
# Out:
#                                               Tweets  len                  ID  \
# 0  RT @CanalCapital: ¡Gracias por estar siempre a...  140  997107105462128640
# 1  ¿Sabes por qué en el sector salud de Bogotá to...  129  997106733754605569
# 2  Cerca de 20 mil colaboradores relataron su día...  130  997100833014677504
# 3  RT @GobiernoBTA: Gobierno va con toda en el Re...  140  997097926525640705
# 4  #BuenasNoticias En #LaNuevaBogotá ya son 20 Ce...  140  997082108739948544
# 5  La Subred Sur Occidente cuenta con 5 Centros d...  140  997081541028274176
# 6  La Subred Centro Oriente cuenta con 4 Centros ...  139  997081289734918150
# 7  Los Centros de Atención Prioritaria en Salud C...  140  997081051716603904
# 8  Los Centros de Atención Prioritaria en Salud h...  140  997080854013849600
# 9  Ahora más bogotanos pueden acceder a los servi...  140  997080711629869057
#
#                  Date               Source  Likes  RTs  SA
# 0 2018-05-17 13:30:33  Twitter for Android      0    1  -1
# 1 2018-05-17 13:29:05         Media Studio      3    5   0
# 2 2018-05-17 13:05:38         Media Studio      0    2   0
# 3 2018-05-17 12:54:05   Twitter Web Client      0  106   0
# 4 2018-05-17 11:51:14  Twitter for Android      1    3   0
# 5 2018-05-17 11:48:58  Twitter for Android      0    0   0
# 6 2018-05-17 11:47:59  Twitter for Android      0    0   0
# 7 2018-05-17 11:47:02  Twitter for Android      0    0   0
# 8 2018-05-17 11:46:15  Twitter for Android      0    0   0
# 9 2018-05-17 11:45:41  Twitter for Android      2    1   0

# %%
pos_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] < 0]

# %%
print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(data['Tweets'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(data['Tweets'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(data['Tweets'])))
# Out:
# Percentage of positive tweets: 2.5%
# Percentage of neutral tweets: 95.0%
# Percentage de negative tweets: 2.5%
