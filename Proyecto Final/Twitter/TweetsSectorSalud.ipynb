# %%
import sys
import pandas as pd
import pickle
import numpy as np
import nltk
nltk.download()
from nltk.book import *
from nltk import word_tokenize
from nltk.corpus import stopwords
import datetime
from datetime import datetime
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [18.0, 8.0]
import re
import string 
import dateparser
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
f= open('SectorSalud_R.txt','rU')
raw=f.read()
text = nltk.word_tokenize(raw)
SectorSTweets = nltk.Text(text)
SectorSTweets.decode("utf-16")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-3c689105f9f7> in <module>()
#       3 text = nltk.word_tokenize(raw)
#       4 SectorSTweets = nltk.Text(text)
# ----> 5 SectorSTweets.decode("utf-16")
#
# AttributeError: 'Text' object has no attribute 'decode'

# %%
list(SectorSTweets)
# Out:
# ['ÿþ',
#  "''",
#  '\x00',
#  ',',
#  '\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00t\x00e\x00x\x00t\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00',
#  ',',
#  '\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00r\x00e\x00t\x00w\x00e\x00e\x00t\x00_\x00c\x00o\x00u\x00n\x00t\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00',
#  ',',
#  '\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00f\x00a\x00v\x00o\x00r\x00i\x00t\x00e\x00_\x00c\x00o\x00u\x00n\x00t\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00',
#  ',',
#  '\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00f\x00a\x00v\x00o\x00r\x00i\x00t\x00e\x00d\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00',
#  ',',
#  '\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00t\x00r\x00u\x00n\x00c\x00a\x00t\x00e\x00d\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00',
#  ',',
#  '\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00i\x00d\x00_\x00s\x00t\x00r\x00',
#  "''",
#  '\x00',
#  "''",
#  '\x00',
#  ',',
#  '\x00',
#  "''",
#  '\x00',
#  "''",
# ...

# %%
SectorSTweets.concordance("Enfermedad")
# Out:
# No matches

# %%
SectorSTweets.concordance("Esquizofrenia")
# Out:
# No matches

# %%
SectorSTweets.concordance("Bipolar")
# Out:
# No matches

# %%
SectorSTweets.concordance("SaludMental")
# Out:
# No matches

# %%
SectorSTweets.concordance("salud_mental")
# Out:
# No matches

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-cc6382e04d28> in <module>()
# ----> 1 tweetsMinSalud.concordance("SaludMental")
#
# AttributeError: 'str' object has no attribute 'concordance'

# %%
SectorSTweets.concordance("Mental")
# Out:
# No matches

# %%
len(SectorSTweets)
# Out:
# 68821
